# %%
"""
Plotting the emissivity tables

Emissivity Tables are saved on scinet.  Pieced together how to use the hdf5 from make_maps_perrgn and make_maps_opt_locs.

Halpha lineind is 9 (from make_maps_opt_locs)
Lyalpha linind is 1 (from make_maps_opt_locs)

In [41]: tablefile.keys()
Out[41]: [u'header', u'lambda', u'lines', u'logd', u'logt']

In [53]: tablefile.values()
Out[53]: 
[<HDF5 group "/header" (4 members)>,
 <HDF5 dataset "lambda": shape (35,), type "|S12">,
 <HDF5 dataset "lines": shape (131, 46, 35), type "<f8">,
 <HDF5 dataset "logd": shape (46,), type "<f4">,
 <HDF5 dataset "logt": shape (131,), type "<f4">]

logrhocm3 == lognHcm3 (presumed from make_maps_perrgn)

In [44]: lambdas
Out[44]: 
array(['H  1  1026A', 'H  1  1216A', 'H  1  3798A', 'H  1  3835A',
       'H  1  3889A', 'H  1  3970A', 'H  1  4102A', 'H  1  4340A',
       'H  1  4861A', 'H  1  6563A', 'H  1 1.094m', 'H  1 1.282m',
       'H  1 1.875m', 'H  1 4.051m', 'H  1 913.3A', 'H  1 913.5A',
       'H  1 913.6A', 'H  1 913.8A', 'H  1 914.0A', 'H  1 914.3A',
       'H  1 914.6A', 'H  1 914.9A', 'H  1 915.3A', 'H  1 915.8A',
       'H  1 916.4A', 'H  1 917.2A', 'H  1 918.1A', 'H  1 919.4A',
       'H  1 921.0A', 'H  1 923.2A', 'H  1 926.2A', 'H  1 930.8A',
       'H  1 937.8A', 'H  1 949.7A', 'H  1 972.5A'], 
      dtype='|S12')

In [5]: wavelen
Out[5]: 
array(['O  1  5577A', 'O  1  6300A', 'O  1  6363A', 'O  1 145.5m',
       'O  1 63.17m', 'O  2 355.6A', 'O  2 356.9A', 'O  2 358.8A',
       'O  2 360.6A', 'O  2 361.8A', 'O  2 366.1A', 'O  2 373.6A',
       'O  2 384.4A', 'O  2 388.4A', 'O  2 414.6A', 'O  2 425.2A',
       'O  2 530.8A', 'O  2 833.8A', 'O  3  1661A', 'O  3  1666A',
       'O  3  2321A', 'O  3  4959A', 'O  3  5007A', 'O  3 206.4A',
       'O  3 215.3A', 'O  3 230.2A', 'O  3 231.1A', 'O  3 232.4A',
       'O  3 233.3A', 'O  3 234.2A', 'O  3 235.5A', 'O  3 236.9A',
       'O  3 238.9A', 'O  3 241.1A', 'O  3 241.2A', 'O  3 244.7A',
       'O  3 248.6A', 'O  3 248.7A', 'O  3 255.4A', 'O  3 263.2A',
       'O  3 263.9A', 'O  3 265.0A', 'O  3 268.1A', 'O  3 276.9A',
       'O  3 280.4A', 'O  3 299.3A', 'O  3 300.5A', 'O  3 305.4A',
       'O  3 373.6A', 'O  3 374.1A', 'O  3 500.7A', 'O  3 51.80m',
       'O  3 698.2A', 'O  3 703.4A', 'O  3 835.0A', 'O  3 88.33m',
       'O  4  1397A', 'O  4  1400A', 'O  4  1401A', 'O  4  1405A',
       'O  4  1407A', 'O  4 145.8A', 'O  4 146.8A', 'O  4 148.1A',
       'O  4 150.1A', 'O  4 152.4A', 'O  4 153.6A', 'O  4 158.6A',
       'O  4 159.7A', 'O  4 165.4A', 'O  4 166.6A', 'O  4 167.1A',
       'O  4 168.1A', 'O  4 168.2A', 'O  4 168.9A', 'O  4 169.9A',
       'O  4 170.7A', 'O  4 171.6A', 'O  4 174.3A', 'O  4 174.7A',
       'O  4 180.3A', 'O  4 181.8A', 'O  4 182.7A', 'O  4 184.2A',
       'O  4 186.0A', 'O  4 188.2A', 'O  4 196.4A', 'O  4 196.6A',
       'O  4 200.8A', 'O  4 203.0A', 'O  4 206.6A', 'O  4 207.6A',
       'O  4 214.8A', 'O  4 239.1A', 'O  4 25.88m', 'O  4 250.3A',
       'O  4 252.5A', 'O  4 260.5A', 'O  4 265.5A', 'O  4 273.5A',
       'O  4 280.5A', 'O  4 549.3A', 'O  4 554.4A', 'O  4 609.4A',
       'O  4 617.0A', 'O  4 779.9A', 'O  4 789.0A', 'O  5  1218A',
       'O  5 112.6A', 'O  5 113.4A', 'O  5 114.6A', 'O  5 116.4A',
       'O  5 118.2A', 'O  5 119.4A', 'O  5 124.9A', 'O  5 135.8A',
       'O  5 139.1A', 'O  5 172.6A', 'O  5 630.0A', 'O  6  1032A',
       'O  6  1038A', 'O  6 105.0A', 'O  6 116.0A', 'O  6 150.0A',
       'O  6 93.24A', 'O  6 94.06A', 'O  6 95.23A', 'O  6 97.00A',
       'O  6 99.86A', 'O  7  1624A', 'O  7  1640A', 'O  7 120.3A',
       'O  7 128.5A', 'O  7 135.8A', 'O  7 17.77A', 'O  7 18.63A',
       'O  7 21.60A', 'O  7 21.80A', 'O  7 21.81A', 'O  7 22.10A',
       'O  7 382.0A', 'O  7 96.15A', 'O  8 102.5A', 'O  8 14.46A',
       'O  8 14.53A', 'O  8 14.64A', 'O  8 14.82A', 'O  8 15.18A',
       'O  8 16.01A', 'O  8 18.97A', 'O  8 75.89A'], 
      dtype='|S12')



author:lokhorst
""";

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# %% [markdown]
# Load the data from the emissivity tables.

# %%
# hydrogen lines
tablefilename = './EmmisivityTables/hydrogen.hdf5'
tablefile = h5py.File(tablefilename, "r")
H_logTK =   np.array(tablefile.get('logt'),dtype=np.float32)
H_logrhocm3 =   np.array(tablefile.get('logd'),dtype=np.float32)
H_lines =   np.array(tablefile.get('lines'),dtype=np.float32)
H_wavelen =   np.array(tablefile.get('lambda'))
tablefile.close()

# oxygen lines in the visible: 0,1,2,21, 22, 
tablefilename = './EmmisivityTables/oxygen.hdf5'
tablefile = h5py.File(tablefilename, "r")
O_logTK =   np.array(tablefile.get('logt'),dtype=np.float32)
O_logrhocm3 =   np.array(tablefile.get('logd'),dtype=np.float32)
O_lines =   np.array(tablefile.get('lines'),dtype=np.float32)
O_wavelen =   np.array(tablefile.get('lambda'))
tablefile.close()

# %%
specnot_dict = {'H  1  1216A':r'Ly$\alpha$ 1216$\mathrm{\AA}$','H  1  6563A':r'H$\alpha$ 6563$\mathrm{\AA}$',
                'O  3  5007A':'[OIII] 5007$\mathrm{\AA}$','O  3  4959A':'[OIII] 4959$\mathrm{\AA}$',
                'O  1  6300A':'OI 6300$\mathrm{\AA}$','O  1  6363A':'OI 6363$\mathrm{\AA}$',
                'O  1  5577A':'OI 5577$\mathrm{\AA}$'}

# %% [markdown]
# Pick out the lines of interest.

# %%
Halpha_emtable = H_lines[:,:,9] 
Lyalpha_emtable = H_lines[:,:,1]

# %% [markdown]
# Pick out the number densities of interest.

# %%
print "log_10 n_H = %s, n_H = %s"%(H_logrhocm3[10],10**H_logrhocm3[10])
print "log_10 n_H = %s, n_H = %s"%(H_logrhocm3[25],10**H_logrhocm3[25])
print "log_10 n_H = %s, n_H = %s"%(H_logrhocm3[40],10**H_logrhocm3[40])

Halpha_nH_0 = Halpha_emtable[:,40]
Lyalpha_nH_0 = Lyalpha_emtable[:,40]

Halpha_nH_3 = Halpha_emtable[:,25]
Lyalpha_nH_3 = Lyalpha_emtable[:,25]

Halpha_nH_6 = Halpha_emtable[:,10]
Lyalpha_nH_6 = Lyalpha_emtable[:,10]

plt.plot(H_logTK,Halpha_nH_3,label=r'H$\alpha$')
# Out:
# log_10 n_H = -6.0, n_H = 1e-06
# log_10 n_H = -3.0, n_H = 0.001
# log_10 n_H = 0.0, n_H = 1.0

# %% [markdown]
# Since more lines of interest for oxygen, going to put it all into a loop.

# %% [markdown]
# ## At solar abundance

# %%
fig,(ax3,ax2,ax1) = plt.subplots(1,3,figsize=(16,6))

#font = {'family' : 'normal',
#        'weight' : 'normal',
#        'size'   : 13}
#
#mpl.rc('font', **font)

SMALL_SIZE = 16
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

reds = plt.get_cmap("Reds")
blues = plt.get_cmap("Blues")

### log10 n_H = 0
ax1.plot(H_logTK,Lyalpha_nH_0,label=r'Ly$\alpha$',color=reds(1.0),linewidth=2)
ax1.plot(H_logTK,Halpha_nH_0,label=r'H$\alpha$',color=reds(1.0),linestyle='--',linewidth=2)
### Solar abundances here -- need to take that into account...  ##
#indices = [0,21,22,2,1]; linestyles = [':','--','-','--','-']; colours = [blues(1.0),blues(1.0),blues(1.0),blues(0.5),blues(0.5)]
indices = [22,21,1,2,0]; linestyles = ['-','--','-','--',':']; colours = [blues(0.5),blues(0.5),blues(1.0),blues(1.0),blues(1.0)]
for index,colour,linestyle in zip(indices,colours,linestyles):
    emtable = O_lines[:,:,index]
    ax1.plot(O_logTK,emtable[:,40],label=O_wavelen[index],color=colour,linestyle=linestyle,linewidth=2)
    
### log10 n_H = -3 
ax2.plot(H_logTK,Lyalpha_nH_3,label=r'Ly$\alpha$',color=reds(1.0),linewidth=2)
ax2.plot(H_logTK,Halpha_nH_3,label=r'H$\alpha$',color=reds(1.0),linestyle='--',linewidth=2)
### Solar abundances here -- need to take that into account...  ##
for index,colour,linestyle in zip(indices,colours,linestyles):
    emtable = O_lines[:,:,index]
    ax2.plot(O_logTK,emtable[:,25],label=O_wavelen[index],color=colour,linestyle=linestyle,linewidth=2)

### log10 n_H = -6
ax3.plot(H_logTK,Lyalpha_nH_6,label=r'Ly$\alpha$',color=reds(1.0),linewidth=2)
ax3.plot(H_logTK,Halpha_nH_6,label=r'H$\alpha$',color=reds(1.0),linestyle='--',linewidth=2)
### Solar abundances here -- need to take that into account...  ##
for index,colour,linestyle in zip(indices,colours,linestyles):
    emtable = O_lines[:,:,index]
    label=specnot_dict[O_wavelen[index]]
    if 'O  3' in label:
        label = label.replace('O  3','[O  3]')
    ax3.plot(O_logTK,emtable[:,10],label=label,color=colour,linestyle=linestyle,linewidth=2)
    
ax3.legend(fancybox=True,loc=1,fontsize=14)
ax1.set_title(r'log$_{10}$ n$_H$ = 0, solar abundance')
ax2.set_title(r'log$_{10}$ n$_H$ = -3, solar abundance')
ax3.set_title(r'log$_{10}$ n$_H$ = -6, solar abundance')

for ax in [ax1,ax2,ax3]:
    ax.set_xlim(3,8)
    ax.set_ylim(-30,-20)
    ax.set_xlabel(r'Log$_{10}$ T (K)')
    ax.set_ylabel(r'Log$_{10}$ $\epsilon / n_H^2$ ($erg$ $s^{-1}$ $cm^3$)')

ax2.set_yticklabels([])
ax2.set_ylabel('')
ax1.set_yticklabels([])
ax1.set_ylabel('')

fig.subplots_adjust( wspace=0.)

plt.tight_layout()
plt.savefig('emissivitytable_threeplots_solar.png')

# %%
O_wavelen[22]
# Out:
# 'O  3  5007A'

# %% [markdown]
# ### automate the above plot for any density

# %%
print H_logrhocm3
print H_logrhocm3[10],H_logrhocm3[25],H_logrhocm3[40],H_logrhocm3[45]
# Out:
# [-8.         -7.80000019 -7.5999999  -7.4000001  -7.19999981 -7.
#  -6.80000019 -6.5999999  -6.4000001  -6.19999981 -6.         -5.80000019
#  -5.5999999  -5.4000001  -5.19999981 -5.         -4.80000019 -4.5999999
#  -4.4000001  -4.19999981 -4.         -3.79999995 -3.5999999  -3.4000001
#  -3.20000005 -3.         -2.79999995 -2.5999999  -2.4000001  -2.20000005
#  -2.         -1.79999995 -1.60000002 -1.39999998 -1.20000005 -1.
#  -0.80000001 -0.60000002 -0.40000001 -0.2         0.          0.2
#   0.40000001  0.60000002  0.80000001  1.        ]
# -6.0 -3.0 0.0 1.0

# %%
# Set up the plot structure based on the number of plots you want to make
fig,axarr = plt.subplots(2,3,figsize=(16,12))
    
SMALL_SIZE = 16
MEDIUM_SIZE = 16
BIGGER_SIZE = 18
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

reds = plt.get_cmap("Reds")
blues = plt.get_cmap("Blues")

def emisplot(ax,density_index = 40,legend=False):
    'plot the H lines'
    indices = [1,9]
    linestyles = ['-','--']
    colours = [reds(1.0),reds(1.0)]
    for index,colour,linestyle in zip(indices,colours,linestyles):
        emtable = H_lines[:,:,index]
        ax.plot(H_logTK,emtable[:,density_index],label=specnot_dict[H_wavelen[index]],color=colour,linestyle=linestyle,linewidth=2)

    'plot the O lines'
    indices = [22,21,1,2,0]
    linestyles = ['-','--','-','--',':']
    colours = [blues(0.5),blues(0.5),blues(1.0),blues(1.0),blues(1.0)]
    for index,colour,linestyle in zip(indices,colours,linestyles):
        emtable = O_lines[:,:,index]
        label=specnot_dict[O_wavelen[index]]
        if 'O  3' in label:
            label = label.replace('O  3','[O  3]')
        ax.plot(O_logTK,emtable[:,density_index],label=label,color=colour,linestyle=linestyle,linewidth=2)

    'add a legend if set to True'
    if legend:
        ax.legend(fancybox=True,loc=1,fontsize=14)
        #ax.legend()
        
    'add the density to the plot'
    label = r'log$_{10}$ n$_H$ = %s'%H_logrhocm3[density_index]
    ax.text(0.05,0.95,label,transform=ax.transAxes,color='black',fontsize=SMALL_SIZE)


emisplot(axarr[0,0],density_index = 20,legend=True)
emisplot(axarr[0,1],density_index = 25,legend=False)
emisplot(axarr[0,2],density_index = 30,legend=False)

emisplot(axarr[1,0],density_index = 35,legend=False)
emisplot(axarr[1,1],density_index = 40,legend=False)
emisplot(axarr[1,2],density_index = 45,legend=False)

'format the plots'
for axx in axarr[:]:
    for ax in axx:
        ax.set_xlim(3,8)
        ax.set_ylim(-30,-20)
        ax.set_xlabel(r'Log$_{10}$ T (K)')
        ax.set_ylabel(r'Log$_{10}$ $\epsilon / n_H^2$ ($erg$ $s^{-1}$ $cm^3$)')
        
    axx[1].set_yticklabels([])
    axx[1].set_ylabel('')
    axx[2].set_yticklabels([])
    axx[2].set_ylabel('')
    
plt.tight_layout()

# %%
fig,axarr = plt.subplots(1,3,figsize=(16,6.5))
emisplot(axarr[0],density_index = 10,legend=True)
emisplot(axarr[1],density_index = 25,legend=False)
emisplot(axarr[2],density_index = 40,legend=False)
'format the plots'
for ax in axarr[:]:
    #for ax in axx:
    ax.set_xlim(3,8)
    ax.set_ylim(-30,-20)
    ax.set_xlabel(r'Log$_{10}$ T (K)')
    ax.set_ylabel(r'Log$_{10}$ $\epsilon / n_H^2$ ($erg$ $s^{-1}$ $cm^3$)')
        
axarr[1].set_yticklabels([])
axarr[1].set_ylabel('')
axarr[2].set_yticklabels([])
axarr[2].set_ylabel('')

# guesstimate the location and then tweak
xmax = 4.9
ymax = -26.9
dx = 0; dy = -2.
axarr[0].arrow(xmax, ymax, dx, dy, head_width=0.1,color='black')

#axarr[0].text(xmax+0.2-1.2,ymax+dy-0.,'[O/H]=-2',fontsize=13,backgroundcolor='white')
#t = axarr[0].text(xmax+0.2-1.2,ymax-0.,'[O/H]= 0',fontsize=13)
#t.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='white'))

s = axarr[0].text(xmax+0.13,ymax+dy-0.1,'[O/H]=-2',fontsize=15,backgroundcolor='white')
s.set_bbox(dict(facecolor='white', alpha=0.8, edgecolor='white'))
t = axarr[0].text(xmax+0.13,ymax-0.1,'[O/H]= 0',fontsize=15)
t.set_bbox(dict(facecolor='white', alpha=0.8, edgecolor='white'))

plt.tight_layout()

plt.savefig('emissivitytable_threeplots_witharrow.png')

# %% [markdown]
# ## Correctly OIII down to a fraction of solar

# %%
fig,(ax3,ax2,ax1) = plt.subplots(1,3,figsize=(16,6))

#font = {'family' : 'normal',
#        'weight' : 'normal',
#        'size'   : 13}
#
#mpl.rc('font', **font)

frac_of_solar = 1.0

# log10 (E/nH^2) = log10(E) - log10(nH^2)
# log10 (0.2 * E/nH^2) = log10(0.2) + log10(E) - log10(nH^2)

SMALL_SIZE = 16
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

reds = plt.get_cmap("Reds")
blues = plt.get_cmap("Blues")

### log10 n_H = 0
ax1.plot(H_logTK,Lyalpha_nH_0,label=r'Ly$\alpha$',color=reds(1.0),linewidth=2)
ax1.plot(H_logTK,Halpha_nH_0,label=r'H$\alpha$',color=reds(1.0),linestyle='--',linewidth=2)
### Solar abundances here -- need to take that into account...  ##
#indices = [0,21,22,2,1]; linestyles = [':','--','-','--','-']; colours = [blues(1.0),blues(1.0),blues(1.0),blues(0.5),blues(0.5)]
indices = [22,21,1,2,0]; linestyles = ['-','--','-','--',':']; colours = [blues(0.5),blues(0.5),blues(1.0),blues(1.0),blues(1.0)]
for index,colour,linestyle in zip(indices,colours,linestyles):
    emtable = O_lines[:,:,index]
    ax1.plot(O_logTK,emtable[:,40]+np.log10(frac_of_solar),label=O_wavelen[index],color=colour,linestyle=linestyle,linewidth=2)
    
### log10 n_H = -3 
ax2.plot(H_logTK,Lyalpha_nH_3,label=r'Ly$\alpha$',color=reds(1.0),linewidth=2)
ax2.plot(H_logTK,Halpha_nH_3,label=r'H$\alpha$',color=reds(1.0),linestyle='--',linewidth=2)
### Solar abundances here -- need to take that into account...  ##
for index,colour,linestyle in zip(indices,colours,linestyles):
    emtable = O_lines[:,:,index]
    ax2.plot(O_logTK,emtable[:,25]+np.log10(frac_of_solar),label=O_wavelen[index],color=colour,linestyle=linestyle,linewidth=2)

### log10 n_H = -6
ax3.plot(H_logTK,Lyalpha_nH_6,label=r'Ly$\alpha$',color=reds(1.0),linewidth=2)
ax3.plot(H_logTK,Halpha_nH_6,label=r'H$\alpha$',color=reds(1.0),linestyle='--',linewidth=2)
### Solar abundances here -- need to take that into account...  ##
for index,colour,linestyle in zip(indices,colours,linestyles):
    emtable = O_lines[:,:,index]
    ax3.plot(O_logTK,emtable[:,10]+np.log10(frac_of_solar),label=O_wavelen[index],color=colour,linestyle=linestyle,linewidth=2)
    
ax3.legend(fancybox=True,loc=1,fontsize=14)
ax1.set_title(r'log$_{10}$ n$_H$ = 0, %s solar abundance'%frac_of_solar)
ax2.set_title(r'log$_{10}$ n$_H$ = -3, %s solar abundance'%frac_of_solar)
ax3.set_title(r'log$_{10}$ n$_H$ = -6, %s solar abundance'%frac_of_solar)

for ax in [ax1,ax2,ax3]:
    ax.set_xlim(3,8)
    ax.set_ylim(-30,-20)
    ax.set_xlabel(r'Log$_{10}$ T (K)')
    ax.set_ylabel(r'Log$_{10}$ $\epsilon / n_H^2$ ($erg$ $s^{-1}$ $cm^3$)')

ax2.set_yticklabels([])
ax2.set_ylabel('')
ax1.set_yticklabels([])
ax1.set_ylabel('')

fig.subplots_adjust( wspace=0.)

plt.tight_layout()
plt.savefig('emissivitytable_threeplots_%ssolar.png'%frac_of_solar)

# %% [markdown]
# ### Plot them all together

# %%
# log10 (E/nH^2) = log10(E) - log10(nH^2)
# log10 (0.2 * E/nH^2) = log10(0.2) + log10(E) - log10(nH^2)

SMALL_SIZE = 16
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

reds = plt.get_cmap("Reds")
blues = plt.get_cmap("Blues")

def emisplot(ax,density_index = 40,legend=False,frac_of_solar = 1.0):
    'plot the H lines'
    indices = [1,9]
    linestyles = ['-','--']
    colours = [reds(1.0),reds(1.0)]
    for index,colour,linestyle in zip(indices,colours,linestyles):
        emtable = H_lines[:,:,index]
        ax.plot(H_logTK,emtable[:,density_index],label=H_wavelen[index],color=colour,linestyle=linestyle,linewidth=2)

    'plot the O lines'
    indices = [22,21,1,2,0]
    linestyles = ['-','--','-','--',':']
    colours = [blues(0.5),blues(0.5),blues(1.0),blues(1.0),blues(1.0)]
    for index,colour,linestyle in zip(indices,colours,linestyles):
        emtable = O_lines[:,:,index]
        label=O_wavelen[index]
        if 'O  3' in label:
            label = label.replace('O  3','[O  3]')
        ax.plot(O_logTK,emtable[:,density_index]+np.log10(frac_of_solar),label=label,color=colour,linestyle=linestyle,linewidth=2)

    'add a legend if set to True'
    if legend:
        ax.legend(fancybox=True,loc=1,fontsize=14)
        
def threeplotsatmet(ax1,ax2,ax3,frac_of_solar = 1.0,legend=True):
    indices = [22,21,1,2,0]; 
    linestyles = ['-','--','-','--',':']; 
    colours = [blues(0.5),blues(0.5),blues(1.0),blues(1.0),blues(1.0)]

    ### log10 n_H = 0
    emisplot(ax1,density_index = 40,frac_of_solar=frac_of_solar)
    
    ### log10 n_H = -3 
    emisplot(ax2,density_index = 25,frac_of_solar=frac_of_solar)

    ### log10 n_H = -6
    emisplot(ax3,density_index = 10,frac_of_solar=frac_of_solar,legend=legend)
        
    for ax,dens in zip([ax1,ax2,ax3],[0.0,-3.0,-6.0]):
        ax.set_xlim(3,8)
        ax.set_ylim(-30,-20)
        ax.set_xlabel(r'Log$_{10}$ T (K)')
        ax.set_ylabel(r'Log$_{10}$ $\epsilon / n_H^2$ ($erg$ $s^{-1}$ $cm^3$)')
        
        'add the density to the plot'
        label = r'log$_{10}$ n$_H$ = %s'%dens
        ax.text(0.05,0.94,label,transform=ax.transAxes,color='black',fontsize=SMALL_SIZE)
        
        'add the abundance to the plot'
        label = '[O/H] = %s'%np.log10(frac_of_solar)
        ax.text(0.05,0.87,label,transform=ax.transAxes,color='black',fontsize=SMALL_SIZE)

# %%
fig,axarr = plt.subplots(1,3,figsize=(16,6))

threeplotsatmet(axarr[2],axarr[1],axarr[0])

for ax in [axarr[2],axarr[1]]:
    ax.set_yticklabels([])
    ax.set_ylabel('')
    ax.set_yticklabels([])
    ax.set_ylabel('')

fig.subplots_adjust( wspace=0.)

plt.tight_layout()
#plt.savefig('emissivitytable_threeplots_%ssolar.png'%frac_of_solar)

# %%
fig,axarr = plt.subplots(3,3,figsize=(18,18))

threeplotsatmet(axarr[0,2],axarr[0,1],axarr[0,0])
threeplotsatmet(axarr[1,2],axarr[1,1],axarr[1,0],frac_of_solar = 0.1,legend=False)
threeplotsatmet(axarr[2,2],axarr[2,1],axarr[2,0],frac_of_solar = 0.01,legend=False)

for ax in [axarr[0,2],axarr[0,1],axarr[1,2],axarr[1,1],axarr[2,2],axarr[2,1]]:
    print ax
    ax.set_yticklabels([])
    ax.set_ylabel('')
    
for ax in [axarr[0,0],axarr[0,1],axarr[0,2],axarr[1,0],axarr[1,1],axarr[1,2]]:
    ax.set_xticklabels([])
    ax.set_xlabel('')

fig.subplots_adjust( wspace=0.05 ,hspace=0.05)

#plt.tight_layout()
plt.savefig('emissivitytable_nineplots_varyabund.png')
# Out:
# Axes(0.672059,0.657941;0.227941x0.222059)
# Axes(0.398529,0.657941;0.227941x0.222059)
# Axes(0.672059,0.391471;0.227941x0.222059)
# Axes(0.398529,0.391471;0.227941x0.222059)
# Axes(0.672059,0.125;0.227941x0.222059)
# Axes(0.398529,0.125;0.227941x0.222059)
